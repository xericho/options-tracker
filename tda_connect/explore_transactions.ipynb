# %% [markdown]
# # Import packages

# %%
import numpy as numpy
import pandas as pd 
import json
from dateparser import parse

# %% [markdown]
# # Load file and preprocess

# %%
with open('../tda_positions.json', 'r') as f:
    positions = json.load(f)['securitiesAccount']['positions']
df_pos = pd.DataFrame(positions)
df_pos['cusip'] = df_pos.instrument.apply(lambda x: x['cusip'])

# %%
INSTRUCTION = {
    'BUY': 1,
    'SELL': -1,
}
df = pd.read_json('../tda_transactions.json')  
df = df[df.transactionSubType != 'IT']  # Ignore this, useless info
df['totalFees'] = df.fees.apply(lambda x: sum(x.values()))
df['cusip'] = df.transactionItem.apply(lambda x: x['instrument']['cusip'])
df['transactionDate'] = df.transactionDate.apply(lambda x: parse(x))

# For closed options
df_trade = df[df.type == 'TRADE']
# Extract orderId without extra data
df_trade['orderId_base'] = df_trade.orderId.apply(lambda x: str(x).split('.')[0])
# Create column for ticker symbol
df_trade['ticker'] = df_trade.transactionItem.apply(lambda x: x['instrument']['underlyingSymbol'])
df_trade['score'] = df_trade.transactionItem.apply(lambda x: x['amount'] * INSTRUCTION[x['instruction']])
df_trade['position_effect'] = df_trade.transactionItem.apply(lambda x: x['positionEffect'])
# df_trade = removePositions(df_trade, positions)

# For expired options
df_expired = df[df.type == 'RECEIVE_AND_DELIVER']
df_expired['score'] = df_expired.transactionItem.apply(lambda x: x['amount'])

df_trade.head()
# Out:
#     type  subAccount settlementDate       orderId  netAmount  \
# 0  TRADE           1     2021-02-16  2.114929e+09    -621.33
# 1  TRADE           1     2021-02-16  2.113482e+09    -187.66
# 2  TRADE           1     2021-02-16  2.112548e+09     589.33
# 3  TRADE           1     2021-02-12  2.105435e+09    -106.66
# 4  TRADE           1     2021-02-12  2.105036e+09    -205.66
#
#              transactionDate                 orderDate transactionSubType  \
# 0  2021-02-12 20:55:58+00:00  2021-02-12T20:55:58+0000                 BY
# 1  2021-02-12 19:28:54+00:00  2021-02-12T19:28:54+0000                 BY
# 2  2021-02-12 18:29:12+00:00  2021-02-12T18:29:12+0000                 SL
# 3  2021-02-11 20:50:03+00:00  2021-02-11T20:50:03+0000                 BY
# 4  2021-02-11 20:22:38+00:00  2021-02-11T20:22:38+0000                 BY
#
#    transactionId  cashBalanceEffectFlag description  \
# 0    32599479264                   True   BUY TRADE
# 1    32595505344                   True   BUY TRADE
# 2    32594042581                   True  SELL TRADE
# 3    32550799584                   True   BUY TRADE
# 4    32549921079                   True   BUY TRADE
#
#                                                 fees  \
# 0  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 1  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 2  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 3  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 4  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                      transactionItem  totalFees  \
# 0  {'accountId': 275422611, 'amount': 2.0, 'price...       1.36
# 1  {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 2  {'accountId': 275422611, 'amount': 1.0, 'price...       0.69
# 3  {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 4  {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
#
#               cusip orderId_base ticker  score position_effect
# 0  0APHA.CJ10020000   2114929104   APHA    2.0         OPENING
# 1  0FUBO.BJ10050000   2113482419   FUBO    1.0         OPENING
# 2  0LAZR.CJ10040000   2112547960   LAZR   -1.0         CLOSING
# 3  0DIS..BJ10220000   2105434757    DIS    1.0         OPENING
# 4  0NPA..CJ10030000   2105035741    NPA    1.0         OPENING

# %% [markdown]
# # Group based on strategy

# %%
# Group by OrderId base, multi-legged orders will have a suffex with the same order id
# Ex: For spreads, 123456.1 and 123456.2 will be grouped together because there's 2
# orders with the same base order id 
df_grouped = df_trade.groupby(['orderId_base']).count()
counts = df_grouped.type.unique()
# Get index for different strategies
indices = {c: df_grouped[df_grouped.type == c].index.to_list() for c in counts}
# Get df for each strategy 
df_legs_raw = {c: df_trade[df_trade.orderId_base.isin(indices[c])] for c in counts}
# Regroup some dfs because some might not actually be 4 leg strategies
df_legs = {c: pd.DataFrame(columns=df_trade.columns) for c in counts}
for c in counts[counts > 2]:  # Skip basic and spread strategies because those are correct
    ticker_group = df_legs_raw[c].groupby(['ticker'])
    for ticker in ticker_group.groups.keys():
        group = ticker_group.get_group(ticker)
        # Use unique cusip to find out if there is actually the correct
        # amount of unique legs
        num_unique_cusip = len(group.groupby(['cusip']).groups.keys())
        # Add these to spread strategy 
        df_legs[num_unique_cusip] = df_legs[num_unique_cusip].append(group, ignore_index=True)

# Add original df_legs to fixed
for c in [1, 2]: 
    df_legs[c] = df_legs[c].append(df_legs_raw[c], ignore_index=True)

# %% [markdown]
# # Group Basic Options

# %%
df_legs[1].cusip
# Out:
# 0      0FUBO.BJ10050000
# 1      0SPCE.BJ10055000
# 2      0TGT..BJ10200000
# 3      0TGT..BJ10200000
# 4      0SPCE.BJ10055000
#              ...
# 679    0AAL..J200013000
# 680    0INTC.II00053000
# 681    0AES..JG00019000
# 682    0SPY..I800342000
# 683    0INTC.II00053000
# Name: cusip, Length: 684, dtype: object

# %%
group = df_legs[1].groupby(['cusip']).get_group('0NIO..BJ10065000').groupby(['position_effect'])
'BY' in group.get_group('OPENING').groupby(['transactionSubType']).groups
# Out:
# True

# %%
group.get_group('CLOSING').groupby(['transactionSubType']).get_group('SL')
# Out:
#      type subAccount settlementDate       orderId  netAmount  \
# 64  TRADE          2     2021-02-02  2.021617e+09     432.66
#
#               transactionDate                 orderDate transactionSubType  \
# 64  2021-02-01 15:10:02+00:00  2021-02-01T15:09:59+0000                 SL
#
#    transactionId cashBalanceEffectFlag description  \
# 64   31961629943                  True  SELL TRADE
#
#                                                  fees  \
# 64  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                       transactionItem  totalFees  \
# 64  {'accountId': 275422611, 'amount': 2.0, 'price...       1.38
#
#                cusip orderId_base ticker  score position_effect
# 64  0NIO..BJ10065000   2021616769    NIO   -2.0         CLOSING

# %%
def groupCompleteOrders(df, expired, cusip):
    """
    Combines opened and closed orders
    :return: dict for pairs and df for remaining
    """

    # Cases for incomplete orders
    if len(group) == 1 or 'CLOSING' not in group.position_effect.to_list():
        print('\t> Checking expired orders...')
        pairs, remaining = getPairs(df, expired, cusip)
        return pairs, remaining

    # Get open and closed orders
    position_effect = df.groupby(['position_effect'])
    opening = position_effect.get_group('OPENING').groupby(['transactionSubType'])
    closing = position_effect.get_group('CLOSING').groupby(['transactionSubType'])

    all_pairs = []
    remaining1 = pd.DataFrame(columns=group.columns)
    remaining2 = pd.DataFrame(columns=group.columns)

    if 'BY' in opening.groups: 
        BTO = opening.get_group('BY')
        STC = closing.get_group('SL')
        data = BTO.append(STC).sort_values(by=['transactionDate'], ascending=True)
        pairs, remaining1 = getPairs(data, expired, cusip)
        all_pairs += pairs

    if 'SL' in opening.groups: 
        STO = opening.get_group('SL')
        BTC = closing.get_group('BY')
        data = STO.append(BTC).sort_values(by=['transactionDate'], ascending=True)
        pairs, remaining2 = getPairs(data, expired, cusip)
        all_pairs += pairs
    
    remaining = remaining1.append(remaining2)
    return all_pairs, remaining

def getPairs(df, expired, cusip):
    counter = 0
    pair = []
    pairs = []
    for idx, row in df.iterrows():
        counter += row.score
        pair.append(idx)

        # Save pair and reinit
        if counter == 0:
            pairs.append(pair)
            pair = []

    # Extract actual rows
    pairs = [df.loc[p] for p in pairs]
    remainder = pd.DataFrame(columns=df.columns)

    if counter != 0:
        # Extract remaining orders
        remainder = df.loc[pair]
        group = expired[expired.cusip == cusip]
        # Just check if the leftover score is in df_expired
        if abs(counter) == group.score.sum():
            pairs.append(remainder.append(group))
            # Remove resolved expired orders
            print('\t> Resolved expired!')
            expired.drop(group.index)
            remainder = pd.DataFrame(columns=df.columns)
        else:
            print('\t> Added to remainder')
            print(remainder)
            print()

    return pairs, remainder


groups = df_legs[1].groupby(['cusip'])
basicOrders = []
remainders = pd.DataFrame(columns=df_trade.columns)
# Loop through each cusip group
for cusip in groups.groups.keys():
    print(cusip)
    # Sort by date, oldest -> recent 
    group = groups.get_group(cusip)
    # Find complete orders
    pairs, remainder = groupCompleteOrders(group, df_expired, cusip) 
    basicOrders += pairs
    remainders = remainders.append(remainder)
# Out:
# 0AAL..J200013000
# 0AAPL.BC10137000
# 0AAPL.C510140000
# 	> Checking expired orders
# 3.0
# REMAINDER FOUND:
#      type subAccount settlementDate       orderId  netAmount  \
# 48  TRADE          1     2021-02-09  2.068868e+09    -913.99
#
#               transactionDate                 orderDate transactionSubType  \
# 48  2021-02-08 16:08:50+00:00  2021-02-08T16:08:49+0000                 BY
#
#    transactionId cashBalanceEffectFlag description  \
# 48   32186081337                  True   BUY TRADE
#
#                                                  fees  \
# 48  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                       transactionItem  totalFees  \
# 48  {'accountId': 275422611, 'amount': 3.0, 'price...       2.03
#
#                cusip orderId_base ticker  score position_effect
# 48  0AAPL.C510140000   2068867797   AAPL    3.0         OPENING
#
# 0AAPL.JN00130000
# 0AAPL.LV00130000
# 0AAPL.WD00116000
# 0ACB..AM10010500
# 0ACB..LB00012000
# 0ACB..LV00011000
# 0AES..JG00019000
# 0AES..LI00022000
# 	> Checking expired orders
# -10.0
# REMAINDER FOUND:
#       type subAccount settlementDate       orderId  netAmount  \
# 379  TRADE          2     2020-12-03  1.742148e+09     143.34
#
#                transactionDate                 orderDate transactionSubType  \
# 379  2020-12-02 15:11:12+00:00  2020-12-02T15:11:12+0000                 SL
#
#     transactionId cashBalanceEffectFlag description  \
# 379   30402329668                  True  SELL TRADE
#
#                                                   fees  \
# 379  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                        transactionItem  totalFees  \
# 379  {'accountId': 275422611, 'amount': 10.0, 'pric...        6.8
#
#                 cusip orderId_base ticker  score position_effect
# 379  0AES..LI00022000   1742148262    AES  -10.0         CLOSING
#
# 0AMC..B510040000
# 	> Checking expired orders
# 3.0
# REMAINDER FOUND:
#      type subAccount settlementDate       orderId  netAmount  \
# 74  TRADE          2     2021-02-01  2.013944e+09    -232.66
# 80  TRADE          2     2021-02-01  2.013336e+09    -641.33
#
#               transactionDate                 orderDate transactionSubType  \
# 74  2021-01-29 17:54:52+00:00  2021-01-29T17:54:44+0000                 BY
# 80  2021-01-29 17:26:43+00:00  2021-01-29T17:26:43+0000                 BY
#
#    transactionId cashBalanceEffectFlag description  \
# 74   31892019862                  True   BUY TRADE
# 80   31890379754                  True   BUY TRADE
#
#                                                  fees  \
# 74  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 80  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                       transactionItem  totalFees  \
# 74  {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 80  {'accountId': 275422611, 'amount': 2.0, 'price...       1.36
#
#                cusip orderId_base ticker  score position_effect
# 74  0AMC..B510040000   2013944498    AMC    1.0         OPENING
# 80  0AMC..B510040000   2013336471    AMC    2.0         OPENING
#
# 0AMD..BJ10090000
# 0AMD..BJ10092500
# 0AMD..BJ10100000
# 0AMD..LO00095000
# 0AMD..LV00100000
# 0BA...A810230000
# 0BA...LB00230000
# 0BA...LB00240000
# 0BA...LI00230000
# 0BABA.A810300000
# 0BABA.AF10250000
# 0BABA.KK00300000
# 	> Checking expired orders
# -2.0
# REMAINDER FOUND:
#       type subAccount settlementDate       orderId  netAmount  \
# 582  TRADE          2     2020-11-09  1.649657e+09    1598.63
#
#                transactionDate                 orderDate transactionSubType  \
# 582  2020-11-06 19:04:24+00:00  2020-11-06T19:04:20+0000                 SL
#
#     transactionId cashBalanceEffectFlag description  \
# 582   29878882560                  True  SELL TRADE
#
#                                                   fees  \
# 582  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                        transactionItem  totalFees  \
# 582  {'accountId': 275422611, 'amount': 2.0, 'price...       1.44
#
#                 cusip orderId_base ticker  score position_effect
# 582  0BABA.KK00300000   1649657370   BABA   -2.0         CLOSING
#
# 0BABA.KR00280000
# 0BABA.L400265000
# 0BABA.LI00270000
# 0BABA.LI00300000
# 0BABA.LO00260000
# 0BABA.NC10270000
# 0BB...BJ10025000
# 0BB...BJ10040000
# 0BBY..BJ10120000
# 0BLDP.LI00021000
# 0BLNK.B510050000
# 0BLNK.BJ10060000
# 0BLNK.NC10052000
# 0CAT..LB00180000
# 0CCL..WD00018000
# 0CGC..BC10046000
# 0CGC..CJ10050000
# 0CGC..KD00021500
# 0CGC..KK00020000
# 0CGC..LI00030000
# 0CGC..LO00030000
# 0CGC..LV00030000
# 0CGC..NC10041000
# 0CHWY.JU00070000
# 0CHWY.JU00075000
# 0CHWY.KD00070000
# 0CHWY.KK00062000
# 0CHWY.W600068000
# 0CHWY.XV00100000
# 0CLOV.BJ10015000
# 0CLOV.BJ10020000
# 0CVS..LV00075000
# 0DDOG.KR00090000
# 0DIS..WK00143000
# 0DKNG.BJ10055000
# 0DKNG.KD00045000
# 0DKNG.L400055000
# 0DKNG.LI00060000
# 0ELY..OJ10030000
# 0ENPH.LI00140000
# 0EWZ..XI00033000
# 	> Checking expired orders
# -3.0
# REMAINDER FOUND:
#       type subAccount settlementDate       orderId  netAmount  \
# 374  TRADE          2     2020-12-04  1.746922e+09      124.0
#
#                transactionDate                 orderDate transactionSubType  \
# 374  2020-12-03 14:33:30+00:00  2020-12-03T14:33:29+0000                 SL
#
#     transactionId cashBalanceEffectFlag description  \
# 374   30431887393                  True  SELL TRADE
#
#                                                   fees  \
# 374  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                        transactionItem  totalFees  \
# 374  {'accountId': 275422611, 'amount': 3.0, 'price...       2.04
#
#                 cusip orderId_base ticker  score position_effect
# 374  0EWZ..XI00033000   1746922436    EWZ   -3.0         CLOSING
#
# 0FB...KR00300000
# 0FB...WD00280000
# 0FSLY.LI00105000
# 0FSLY.V900110000
# 0FSR..BJ10017500
# 0FUBO.AT10040000
# 0FUBO.B510040000
# 0FUBO.B510050000
# 0FUBO.B510050500
# 0FUBO.BJ10035000
# 0FUBO.BJ10036000
# 0FUBO.BJ10050000
# 4.0
# REMAINDER FOUND:
#      type subAccount settlementDate       orderId  netAmount  \
# 68  TRADE          2     2021-02-02  2.020613e+09    -875.66
# 40  TRADE          1     2021-02-09  2.073411e+09    -360.66
# 26  TRADE          1     2021-02-11  2.093879e+09    -320.66
# 0   TRADE          1     2021-02-16  2.113482e+09    -187.66
#
#               transactionDate                 orderDate transactionSubType  \
# 68  2021-02-01 14:42:42+00:00  2021-02-01T14:42:41+0000                 BY
# 40  2021-02-08 20:37:11+00:00  2021-02-08T20:37:11+0000                 BY
# 26  2021-02-10 20:13:36+00:00  2021-02-10T20:13:36+0000                 BY
# 0   2021-02-12 19:28:54+00:00  2021-02-12T19:28:54+0000                 BY
#
#    transactionId cashBalanceEffectFlag description  \
# 68   31959514035                  True   BUY TRADE
# 40   32194186254                  True   BUY TRADE
# 26   32282562790                  True   BUY TRADE
# 0    32595505344                  True   BUY TRADE
#
#                                                  fees  \
# 68  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 40  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 26  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 0   {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                       transactionItem  totalFees  \
# 68  {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 40  {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 26  {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 0   {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
#
#                cusip orderId_base ticker  score position_effect
# 68  0FUBO.BJ10050000   2020612808   FUBO    1.0         OPENING
# 40  0FUBO.BJ10050000   2073411087   FUBO    1.0         OPENING
# 26  0FUBO.BJ10050000   2093878719   FUBO    1.0         OPENING
# 0   0FUBO.BJ10050000   2113482419   FUBO    1.0         OPENING
#
# 0FUBO.BJ10060000
# 0GHIV.BJ10015000
# 0HD...AM10270000
# 0INTC.II00053000
# 0INTC.JU00055000
# 0JKS..AF10070000
# 	> Checking expired orders
# 1.0
# 	> Resolved expired!
# 0JKS..AF10075000
# 0JKS..BJ10070000
# 0JKS..BJ10075000
# 0JKS..JG00060000
# 0JKS..JG00065000
# 0JKS..JG00070000
# 0JKS..KK00070000
# 0JKS..KK00080000
# 0JKS..KK00090000
# -2.0
# REMAINDER FOUND:
#       type subAccount settlementDate       orderId  netAmount  \
# 653  TRADE          2     2020-10-22  1.597189e+09    -770.66
# 649  TRADE          2     2020-10-22  1.598652e+09    1116.98
#
#                transactionDate                 orderDate transactionSubType  \
# 653  2020-10-21 14:22:46+00:00  2020-10-21T14:22:46+0000                 BY
# 649  2020-10-21 17:38:01+00:00  2020-10-21T17:38:01+0000                 SL
#
#     transactionId cashBalanceEffectFlag description  \
# 653   29555837243                  True   BUY TRADE
# 649   29559485825                  True  SELL TRADE
#
#                                                   fees  \
# 653  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 649  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                        transactionItem  totalFees  \
# 653  {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 649  {'accountId': 275422611, 'amount': 3.0, 'price...       2.08
#
#                 cusip orderId_base ticker  score position_effect
# 653  0JKS..KK00090000   1597189052    JKS    1.0         OPENING
# 649  0JKS..KK00090000   1598651861    JKS   -3.0         CLOSING
#
# 0JKS..KK00100000
# 0JKS..LI00065000
# 0JKS..VG00060000
# 0JKS..VG00065000
# 0JKS..WK00055000
# 0JKS..WK00060000
# 0JMIA.AF10045000
# 0JMIA.KK00014000
# 0JNJ..AF10160000
# 0JNJ..XI00149000
# 0LAZR.B510034000
# 0LAZR.BJ10040000
# 0LAZR.CJ10040000
# 0LI...KK00045000
# 0LI...L400045000
# 0LOGI.LI00090000
# 0LUV..WD00042000
# 0LYFT.JN00028000
# 	> Checking expired orders
# 1.0
# 	> Resolved expired!
# 0MOMO.KR00017500
# 0MP...BJ10040000
# 0MSFT.L400220000
# 0MU...AF10072500
# 0MU...JU00050000
# 0MU...JU00054000
# 0MU...WK00060000
# 0MU...WK00060500
# 0MU...WK00061500
# 0NEE..BJ10085000
# 0NFLX.BC10565000
# 0NFLX.L400510000
# 0NFLX.LB00500000
# 0NFLX.LI00540000
# 0NFLX.NC10550000
# 0NIO..A810055000
# 0NIO..AF10045000
# 0NIO..AF10052000
# 0NIO..AF10057000
# 0NIO..AM10050000
# 0NIO..AM10057000
# 0NIO..AT10065000
# 0NIO..B510057500
# 0NIO..BC10060000
# 0NIO..BJ10065000
# 0NIO..BJ10066000
# 0NIO..JN00030000
# 0NIO..JU00028000
# 0NIO..KD00033000
# 0NIO..KD00038000
# 0NIO..KD00045000
# 0NIO..KK00035000
# 0NIO..KK00050000
# 0NIO..KK00053000
# 0NIO..KR00040000
# 0NIO..KR00045000
# 0NIO..L400050000
# 0NIO..L400060000
# 0NIO..LB00045000
# 	> Checking expired orders
# -3.0
# REMAINDER FOUND:
#       type subAccount settlementDate       orderId  netAmount  \
# 337  TRADE          2     2020-12-11  1.777918e+09      193.0
#
#                transactionDate                 orderDate transactionSubType  \
# 337  2020-12-10 14:35:01+00:00  2020-12-10T14:35:01+0000                 SL
#
#     transactionId cashBalanceEffectFlag description  \
# 337   30608639237                  True  SELL TRADE
#
#                                                   fees  \
# 337  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                        transactionItem  totalFees  \
# 337  {'accountId': 275422611, 'amount': 3.0, 'price...       2.04
#
#                 cusip orderId_base ticker  score position_effect
# 337  0NIO..LB00045000   1777918236    NIO   -3.0         CLOSING
#
# 0NIO..LB00055000
# 0NIO..LI00050000
# 0NIO..LI00055000
# 0NIO..LO00055000
# 0NIO..LV00044000
# 0NIO..LV00055000
# 0NIO..MM10060000
# 0NIO..V200021000
# 0NIO..VG00026000
# 0NIO..VG00029000
# 0NIO..W600031000
# 0NIO..W600039000
# 0NIO..W600041000
# 0NIO..W600042000
# 0NPA..CJ10030000
# 	> Checking expired orders
# 2.0
# REMAINDER FOUND:
#      type subAccount settlementDate       orderId  netAmount  \
# 33  TRADE          1     2021-02-10  2.082214e+09    -320.66
# 35  TRADE          1     2021-02-10  2.081316e+09    -495.66
#
#               transactionDate                 orderDate transactionSubType  \
# 33  2021-02-09 19:22:08+00:00  2021-02-09T19:22:08+0000                 BY
# 35  2021-02-09 18:22:58+00:00  2021-02-09T18:22:41+0000                 BY
#
#    transactionId cashBalanceEffectFlag description  \
# 33   32236955573                  True   BUY TRADE
# 35   32235541474                  True   BUY TRADE
#
#                                                  fees  \
# 33  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 35  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                       transactionItem  totalFees  \
# 33  {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 35  {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
#
#                cusip orderId_base ticker  score position_effect
# 33  0NPA..CJ10030000   2082213556    NPA    1.0         OPENING
# 35  0NPA..CJ10030000   2081315789    NPA    1.0         OPENING
#
# 0PFE..LI00041000
# 0PINS.KD00065000
# 0PINS.KK00060000
# 0PINS.KR00060000
# 0PINS.LO00075000
# 0PINS.LV00075000
# 0PLTR.A810035000
# 0PLTR.A810040000
# 0PLTR.AM10025000
# 0PLTR.AM10027500
# 0PLTR.AT10027000
# 0PLTR.AT10030000
# 0PLTR.BJ10030000
# 0PLTR.BJ10040000
# 4.0
# REMAINDER FOUND:
#       type subAccount settlementDate       orderId  netAmount  \
# 157  TRADE          2     2021-01-26  1.966812e+09   -1156.99
# 153  TRADE          2     2021-01-26  1.969240e+09    -463.33
# 148  TRADE          2     2021-01-26  1.971603e+09    -579.33
# 142  TRADE          2     2021-01-27  1.978030e+09     987.98
# 109  TRADE          2     2021-01-28  1.987031e+09    -717.33
# 100  TRADE          2     2021-01-29  1.998728e+09    1168.64
#
#                transactionDate                 orderDate transactionSubType  \
# 157  2021-01-25 14:48:31+00:00  2021-01-25T14:48:22+0000                 BY
# 153  2021-01-25 16:11:15+00:00  2021-01-25T16:11:15+0000                 BY
# 148  2021-01-25 18:54:33+00:00  2021-01-25T18:54:33+0000                 BY
# 142  2021-01-26 16:44:56+00:00  2021-01-26T16:44:56+0000                 SL
# 109  2021-01-27 15:28:13+00:00  2021-01-27T15:28:13+0000                 BY
# 100  2021-01-28 14:35:44+00:00  2021-01-28T14:35:44+0000                 SL
#
#     transactionId cashBalanceEffectFlag description  \
# 157   31689918322                  True   BUY TRADE
# 153   31695040780                  True   BUY TRADE
# 148   31700734330                  True   BUY TRADE
# 142   31737160547                  True  SELL TRADE
# 109   31775107068                  True   BUY TRADE
# 100   31828930277                  True  SELL TRADE
#
#                                                   fees  \
# 157  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 153  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 148  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 142  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 109  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 100  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                        transactionItem  totalFees  \
# 157  {'accountId': 275422611, 'amount': 3.0, 'price...       2.03
# 153  {'accountId': 275422611, 'amount': 2.0, 'price...       1.36
# 148  {'accountId': 275422611, 'amount': 2.0, 'price...       1.36
# 142  {'accountId': 275422611, 'amount': 3.0, 'price...       2.08
# 109  {'accountId': 275422611, 'amount': 2.0, 'price...       1.36
# 100  {'accountId': 275422611, 'amount': 2.0, 'price...       1.42
#
#                 cusip orderId_base ticker  score position_effect
# 157  0PLTR.BJ10040000   1966812225   PLTR    3.0         OPENING
# 153  0PLTR.BJ10040000   1969240242   PLTR    2.0         OPENING
# 148  0PLTR.BJ10040000   1971602767   PLTR    2.0         OPENING
# 142  0PLTR.BJ10040000   1978029867   PLTR   -3.0         CLOSING
# 109  0PLTR.BJ10040000   1987031196   PLTR    2.0         OPENING
# 100  0PLTR.BJ10040000   1998728108   PLTR   -2.0         CLOSING
#
# 0PLTR.BJ10041000
# 0PLTR.KK00012500
# 0PLTR.KK00015000
# 0PLTR.KR00017000
# 0PLTR.LV00030000
# 0PLUG.BJ10070000
# 0PLUG.L400025000
# 0PTON.KK00110000
# 0PTON.LB00120000
# 0PYPL.JU00220000
# 0PYPL.KK00200000
# 0PYPL.LI00210000
# 0QCOM.AF10150000
# 0QCOM.BJ10170000
# 0QCOM.LB00152500
# 0QCOM.LV00150000
# 0QQQ..WK00291000
# 0RIO..BJ10080000
# 0RIOT.LI00008000
# 0SBUX.JU00090000
# 0SE...AF10200000
# 0SE...JU00170000
# 0SE...LI00190000
# 0SE...XB00200000
# 0SLV..BJ10025000
# 0SLV..BJ10030000
# 0SNAP.BJ10057000
# 0SNAP.KR00042000
# 0SOLO.LI00010000
# 0SOLO.LI00012500
# 0SPCE.AF10030000
# 0SPCE.AM10025000
# 0SPCE.AT10034000
# 0SPCE.BJ10055000
# 0SPCE.JN00023000
# 0SPCE.JU00023000
# 0SPCE.JU00025000
# 0SPCE.KK00020000
# 0SPCE.KK00024000
# 0SPCE.LB00026000
# 0SPCE.LB00031000
# 0SPCE.LB00035000
# 0SPCE.MT10040000
# 0SPCE.XI00030000
# 0SPY..I800342000
# 	> Checking expired orders
# 1.0
# 	> Resolved expired!
# 0SPY..KR00360000
# 0SPY..MB10376000
# 	> Checking expired orders
# 2.0
# REMAINDER FOUND:
#       type subAccount settlementDate       orderId  netAmount  \
# 229  TRADE          2     2021-01-12  1.905187e+09      -2.03
#
#                transactionDate                 orderDate transactionSubType  \
# 229  2021-01-11 20:59:33+00:00  2021-01-11T20:59:33+0000                 BY
#
#     transactionId cashBalanceEffectFlag description  \
# 229   31374926378                  True   BUY TRADE
#
#                                                   fees  \
# 229  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                        transactionItem  totalFees  \
# 229  {'accountId': 275422611, 'amount': 2.0, 'price...       0.06
#
#                 cusip orderId_base ticker  score position_effect
# 229  0SPY..MB10376000   1905187109    SPY    2.0         CLOSING
#
# 0SPY..N510375000
# 0SPY..NC10365000
# 0SPY..NC10389000
# 0SPY..NC10390000
# 0SPY..WD00350000
# 0SPY..WD00359000
# 0SPY..WK00355000
# 0SPY..WP00355000
# 0SQ...BJ10220000
# 0SQ...BJ10250000
# 0SQ...KD00185000
# 0SQ...KK00190000
# 0SQ...KR00190000
# 0SQ...LI00220000
# 0SUNW.BJ10030000
# 0SUNW.BJ10035000
# 0T....V200028000
# 0T....V200028500
# 0TGT..BJ10200000
# 0TLRY.KR00009000
# 0TSLA.KK00420000
# 0TSLA.KK00460000
# 0TSLA.KR00450000
# 0TSLA.LI00600000
# 0TSLA.LI00650000
# 0TSLA.LI00800000
# 0TSLA.WK00440000
# 0TSLA.WK00465000
# 0TSLA.XI00635000
# 0TSM..JU00090000
# 0TSM..KK00088000
# 0TSM..L400100000
# 0TSM..LI00100000
# 0TSM..WK00100000
# 0TWTR.AT10048000
# 0TWTR.BJ10046000
# 0TWTR.BJ10046500
# 0TWTR.BJ10047000
# 0TWTR.LI00045000
# 0TWTR.LI00050000
# 0TWTR.XV00054000
# 0UBER.KD00046000
# 0VIXW.W400035000
# 0VLDR.BJ10040000
# 0VXX..K600027000
# 0WBA..NC10050000
# 0WMT..A810150000
# 0XL...BJ10025000
# 0XPEV.A810055000
# 0XPEV.AM10050000
# 0XPEV.BJ10050000
# 0XPEV.LV00050000
# 0XPEV.WK00035000
# 0XPEV.WK00040000
# 0ZM...LI00500000

# %%
group = df_legs[1].groupby(['cusip']).get_group('0AMC..B510040000')
position_effect = group.groupby(['position_effect'])
opening = position_effect.get_group('OPENING').groupby(['transactionSubType'])
closing = position_effect.get_group('CLOSING').groupby(['transactionSubType'])
all_pairs = []
remaining1 = pd.DataFrame(columns=group.columns)
remaining2 = pd.DataFrame(columns=group.columns)
if 'BY' in opening.groups: 
    BTO = opening.get_group('BY')
    STC = closing.get_group('SL')
    data = BTO.append(STC).sort_values(by=['transactionDate'], ascending=True)
    pairs, remaining1 = getPairs(data, df_expired, '0NIO..BJ10065000')
    all_pairs += pairs
if 'SL' in opening.groups: 
    STO = opening.get_group('SL')
    BTC = closing.get_group('BY')
    data = STO.append(BTC).sort_values(by=['transactionDate'], ascending=True)
    pairs, remaining2 = getPairs(data, expired, cusip)
    all_pairs += pairs
remainder = remaining1.append(remaining2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-f4bdc259e30e> in <module>
#       2 position_effect = group.groupby(['position_effect'])
#       3 opening = position_effect.get_group('OPENING').groupby(['transactionSubType'])
# ----> 4 closing = position_effect.get_group('CLOSING').groupby(['transactionSubType'])
#       5 all_pairs = []
#       6 remaining1 = pd.DataFrame(columns=group.columns)
#
# ~/.pyenv/versions/options/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in get_group(self, name, obj)
#     808         inds = self._get_index(name)
#     809         if not len(inds):
# --> 810             raise KeyError(name)
#     811
#     812         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: 'CLOSING'

# %% [markdown]
# # Redo but grouping by cusip first

# %%
def removePositions(df, positions, cusip):
    """ Remove open positions """
    if cusip in df_pos.cusip:
        order_ids = [df[df.cusip == p['instrument']['cusip']].sort_values(by=['transactionSubType'], ascending=False).iloc[0].orderId for p in positions]
        idx_remove = df[df.orderId.isin(order_ids)].index
        return df.drop(idx_remove)
    return df

INSTRUCTION = {
    'BUY': 1,
    'SELL': -1
}
POSITION_EFFECT = {
    'OPEN': 1,
    'CLOSE': -1
}

# %%
df = pd.read_json('../tda_transactions.json')  # Assumes file has no open positions
df['totalFees'] = df.fees.apply(lambda x: sum(x.values()))
df['cusip'] = df.transactionItem.apply(lambda x: x['instrument']['cusip'])
df['transactionDate'] = df.transactionDate.apply(lambda x: parse(x))

gdf = df.groupby(['cusip'])
cusips = list(gdf.groups.keys())
gdf.groups
# Out:
# {'0AAL..J200013000': [1109, 1135], '0AAPL.AT10130000': [245, 248, 334, 337], '0AAPL.AT10131000': [246, 249, 335, 336], '0AAPL.AT10145000': [124, 127, 164], '0AAPL.AT10150000': [126, 129, 166], '0AAPL.AT10155000': [125, 128, 165], '0AAPL.BC10137000': [53, 55], '0AAPL.C510140000': [5, 57], '0AAPL.IB00120000': [1251, 1294], '0AAPL.IB00121250': [1252, 1293], '0AAPL.JN00117000': [979, 1028], '0AAPL.JN00118000': [980, 1027], '0AAPL.JN00130000': [961, 969], '0AAPL.JU00111000': [1032, 1160], '0AAPL.JU00112000': [1031, 1161], '0AAPL.LV00130000': [498, 499, 573], '0AAPL.WD00116000': [756, 759], '0ABNB.AM10155000': [329, 339], '0ABNB.AM10157500': [330, 338], '0ACB..AM10010500': [341, 373], '0ACB..LB00012000': [609, 612], '0ACB..LV00011000': [472, 491], '0ACN..JG00215000': [1133, 1142], '0ACN..JG00217500': [1134, 1143], '0ADBE.AM10480000': [277, 324], '0ADBE.AM10482500': [278, 325], '0ADBE.MF10465000': [284, 406], '0ADBE.MF10470000': [283, 405], '0AES..JG00019000': [1010, 1255], '0AES..LI00022000': [584, 606, 607], '0AI...BJ10170000': [131, 170], '0AI...BJ10180000': [130, 171], '0AMC..B510040000': [79, 80, 96, 102], '0AMD..BJ10090000': [156, 262], '0AMD..BJ10092500': [157, 237], '0AMD..BJ10100000': [78, 103, 114, 116, 117, 135, 137, 159, 187, 192, 195, 221], '0AMD..J200077000': [1144, 1218], '0AMD..J200077500': [1145, 1219], '0AMD..JG00090000': [1019, 1091], '0AMD..JG00092500': [1020, 1090], '0AMD..JN00088000': [884, 1002, 1006], '0AMD..JN00088500': [885, 1003, 1007], '0AMD..K600084000': [865, 994], '0AMD..K600085000': [864, 995], '0AMD..LO00095000': [504, 516], '0AMD..LV00100000': [463, 502], '0AMZN.AT13170000': [270, 296], '0AMZN.AT13175000': [269, 297], '0AMZN.JG03085000': [1130, 1146], '0AMZN.JG03090000': [1129, 1147], '0AMZN.JG03300000': [970, 1046], '0AMZN.JG03310000': [971, 1045], '0AMZN.JN03300000': [923, 982], '0AMZN.JN03305000': [924, 983], '0AMZN.LV03200000': [514, 547], '0AMZN.LV03210000': [515, 548], '0AMZN.MF13245000': [361, 433], '0AMZN.MF13250000': [360, 432], '0APHA.CJ10020000': [0], '0BA...A810230000': [471, 475], '0BA...J200180000': [1216, 1285], '0BA...J200190000': [1217, 1286], '0BA...J900167500': [1088, 1097], '0BA...J900170000': [1089, 1098], '0BA...JG00180000': [1061, 1080], '0BA...JG00182500': [1060, 1079], '0BA...LB00230000': [578, 582, 583], '0BA...LB00240000': [564, 572], '0BA...LI00230000': [577, 586], '0BABA.A810300000': [461, 575], '0BABA.AF10232500': [305, 392], '0BABA.AF10235000': [306, 393], '0BABA.AF10250000': [408, 429], '0BABA.JN00300000': [1000, 1029], '0BABA.JN00302500': [999, 1030], '0BABA.KK00300000': [799, 800, 816, 817, 835], '0BABA.KK00305000': [801, 836], '0BABA.KR00280000': [614, 631, 632, 734, 755, 762], '0BABA.L400265000': [593, 722], '0BABA.LI00270000': [637, 663], '0BABA.LI00300000': [523, 605, 630], '0BABA.LO00260000': [487, 488, 490, 497], '0BABA.MF10210000': [366, 439], '0BABA.MF10215000': [365, 438], '0BABA.NC10270000': [27, 28], '0BB...BJ10025000': [144, 163], '0BB...BJ10040000': [119, 139], '0BBY..BJ10120000': [344, 348, 500], '0BLDP.LI00021000': [538, 549], '0BLNK.B510050000': [206, 225, 243], '0BLNK.BJ10060000': [22, 37, 41, 44], '0BLNK.NC10052000': [10, 24], '0BYND.J900155000': [1105, 1184], '0BYND.J900157500': [1104, 1185], '0BYND.JG00160000': [1200, 1224, 1230, 1238], '0BYND.JG00165000': [1201, 1225, 1231, 1239], '0BYND.JG00200000': [1012, 1035], '0BYND.JG00205000': [1011, 1036], '0BYND.JN00200000': [1038, 1065], '0BYND.JN00205000': [1037, 1066], ...}

# %%
def splitExpiredOrders(df, cusip):
    # For manually closed orders
    df_trade = df[df.type == 'TRADE']
    # Extract orderId without extra data
    df_trade['orderId_base'] = df_trade.orderId.apply(lambda x: str(x).split('.')[0])
    # Create column for ticker symbol
    df_trade['ticker'] = df_trade.transactionItem.apply(lambda x: x['instrument']['underlyingSymbol'])
    df_trade['score'] = df_trade.transactionItem.apply(lambda x: x['amount'] * INSTRUCTION[x['instruction']])
    df_trade['position_effect'] = df_trade.transactionItem.apply(lambda x: x['positionEffect'])
    df_trade = removePositions(df_trade, positions, cusip)

    # For expired options
    df_expired = df[df.type == 'RECEIVE_AND_DELIVER']
    df_expired['score'] = df_expired.transactionItem.apply(lambda x: x['amount'])

    return df_trade, df_expired

def splitByStrategy(df_trade):
    # Group by OrderId base, multi-legged orders will have a suffex with the same order id
    # Ex: For spreads, 123456.1 and 123456.2 will be grouped together because there's 2
    # orders with the same base order id 
    df_grouped = df_trade.groupby(['orderId_base']).count()
    counts = df_grouped.type.unique()
    # Get index for different strategies
    indices = {c: df_grouped[df_grouped.type == c].index.to_list() for c in counts}
    # Get df for each strategy 
    df_legs_raw = {c: df_trade[df_trade.orderId_base.isin(indices[c])] for c in counts}
    # Regroup some dfs because some might not actually be 4 leg strategies
    df_legs = {c: pd.DataFrame(columns=df_trade.columns) for c in counts}
    for c in counts[counts > 2]:  # Skip basic and spread strategies because those are correct
        ticker_group = df_legs_raw[c].groupby(['ticker'])
        for ticker in ticker_group.groups.keys():
            group = ticker_group.get_group(ticker)
            # Use unique cusip to find out if there is actually the correct 
            # amount of unique legs
            num_unique_cusip = len(group.groupby(['cusip']).groups.keys())
            # Add these to spread strategy 
            df_legs[num_unique_cusip] = df_legs[num_unique_cusip].append(group, ignore_index=True)

    # Add original df_legs to fixed
    for c in counts[counts <= 2]: 
        df_legs[c] = df_legs[c].append(df_legs_raw[c], ignore_index=True)
    
    return df_legs

cusip = '0DKNG.J900055000'
g = gdf.get_group(cusip)
trd, exp = splitExpiredOrders(g, cusip)
legs = splitByStrategy(trd)

# %%
legs[1]
# Out:
#     type subAccount settlementDate       orderId  netAmount  \
# 0  TRADE          2     2020-10-02  1.535939e+09    -720.66
# 1  TRADE          2     2020-09-29  1.523605e+09    -498.66
#
#              transactionDate                 orderDate transactionSubType  \
# 0  2020-10-01 16:11:36+00:00  2020-10-01T16:06:44+0000                 BY
# 1  2020-09-28 16:39:23+00:00  2020-09-28T16:39:23+0000                 BY
#
#   transactionId cashBalanceEffectFlag description  \
# 0   29194378390                  True   BUY TRADE
# 1   29071686310                  True   BUY TRADE
#
#                                                 fees  \
# 0  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 1  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                      transactionItem  totalFees  \
# 0  {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 1  {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
#
#               cusip orderId_base ticker  score position_effect
# 0  0DKNG.J900055000   1535938950   DKNG    1.0         CLOSING
# 1  0DKNG.J900055000   1523605449   DKNG    1.0         CLOSING

# %%
df_legs[2]
# Out:
#       type subAccount settlementDate       orderId  netAmount  \
# 0    TRADE          2     2020-09-23  1.504497e+09    -431.32
# 1    TRADE          2     2020-09-23  1.504497e+09    -428.01
# 2    TRADE          2     2020-09-23  1.504497e+09     380.67
# 3    TRADE          2     2020-09-23  1.504497e+09     380.98
# 4    TRADE          2     2021-01-11  1.893203e+09    -623.31
# ..     ...        ...            ...           ...        ...
# 523  TRADE          2     2020-09-04  1.447613e+09     -47.33
# 524  TRADE          2     2020-09-04  1.446187e+09     170.33
# 525  TRADE          2     2020-09-04  1.446187e+09     -61.67
# 526  TRADE          2     2020-09-04  1.446186e+09     359.88
# 527  TRADE          2     2020-09-04  1.446186e+09    -241.12
#
#                transactionDate                 orderDate transactionSubType  \
# 0    2020-09-22 15:33:00+00:00  2020-09-22T15:33:00+0000                 BY
# 1    2020-09-22 15:33:00+00:00  2020-09-22T15:33:00+0000                 BY
# 2    2020-09-22 15:33:00+00:00  2020-09-22T15:33:00+0000                 SL
# 3    2020-09-22 15:33:00+00:00  2020-09-22T15:33:00+0000                 SL
# 4    2021-01-08 15:41:16+00:00  2021-01-08T15:41:15+0000                 BY
# ..                         ...                       ...                ...
# 523  2020-09-03 19:36:02+00:00  2020-09-03T19:31:32+0000                 BY
# 524  2020-09-03 16:53:18+00:00  2020-09-03T16:53:16+0000                 SL
# 525  2020-09-03 16:53:18+00:00  2020-09-03T16:53:16+0000                 BY
# 526  2020-09-03 16:42:11+00:00  2020-09-03T16:42:11+0000                 SL
# 527  2020-09-03 16:42:11+00:00  2020-09-03T16:42:11+0000                 BY
#
#     transactionId cashBalanceEffectFlag description  \
# 0     28954170746                  True   BUY TRADE
# 1     28954170787                  True   BUY TRADE
# 2     28954170965                  True  SELL TRADE
# 3     28954170999                  True  SELL TRADE
# 4     31327548948                  True   BUY TRADE
# ..            ...                   ...         ...
# 523   28613729316                  True   BUY TRADE
# 524   28610609151                  True  SELL TRADE
# 525   28610610639                  True   BUY TRADE
# 526   28610333226                  True  SELL TRADE
# 527   28610333722                  True   BUY TRADE
#
#                                                   fees  \
# 0    {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 1    {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 2    {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 3    {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 4    {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# ..                                                 ...
# 523  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 524  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 525  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 526  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 527  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                        transactionItem  totalFees  \
# 0    {'accountId': 275422611, 'amount': 1.0, 'price...       1.34
# 1    {'accountId': 275422611, 'amount': 1.0, 'price...       0.02
# 2    {'accountId': 275422611, 'amount': 1.0, 'price...       1.36
# 3    {'accountId': 275422611, 'amount': 1.0, 'price...       0.04
# 4    {'accountId': 275422611, 'amount': 1.0, 'price...       1.32
# ..                                                 ...        ...
# 523  {'accountId': 275422611, 'amount': 2.0, 'price...       1.36
# 524  {'accountId': 275422611, 'amount': 1.0, 'price...       0.69
# 525  {'accountId': 275422611, 'amount': 1.0, 'price...       0.69
# 526  {'accountId': 275422611, 'amount': 1.0, 'price...       1.14
# 527  {'accountId': 275422611, 'amount': 1.0, 'price...       1.14
#
#                 cusip orderId_base ticker  score position_effect
# 0    0DKNG.J900054000   1504496655   DKNG    1.0         OPENING
# 1    0DKNG.J900054000   1504496655   DKNG    1.0         OPENING
# 2    0DKNG.J900055000   1504496655   DKNG   -1.0         OPENING
# 3    0DKNG.J900055000   1504496655   DKNG   -1.0         OPENING
# 4    0ETSY.AM10180000   1893203327   ETSY    1.0         OPENING
# ..                ...          ...    ...    ...             ...
# 523  0SPY..I400353000   1447612872    SPY    2.0         OPENING
# 524  0SPY..I400348000   1446186688    SPY   -1.0         OPENING
# 525  0SPY..I400352000   1446186688    SPY    1.0         OPENING
# 526  0VIX..IG00032500   1446186441    VIX   -1.0         OPENING
# 527  0VIX..IG00037500   1446186441    VIX    1.0         OPENING
#
# [528 rows x 19 columns]

# %% [markdown]
# ----
# # Just group by CUSIP and find completed orders

# %%
POSITION = {
    'OPENING': 1,
    'CLOSING': -1
}
df['position_effect'] = df.transactionItem.apply(lambda x: x['amount'] * POSITION[x.get('positionEffect', 'CLOSING')])
df_groups = df.groupby(['cusip'])

# %%
cusips = list(df_groups.groups.keys())
df_open = pd.DataFrame(columns=df.columns)
df_closed = pd.DataFrame(columns=df.columns)
# Loop through each cusip group
for cusip in cusips:
    # print(cusip)
    group = df_groups.get_group(cusip).sort_values(by=['transactionDate'])
    group['cusip'] = cusip
    
    counter = 0
    open_positions = []
    for idx, row in group.iterrows():
        counter += row.position_effect
        open_positions.append(idx)

        # Save pair and reinit
        if counter == 0:
            open_positions = []

    # Add to df
    open = group[group.index.isin(open_positions)]
    df_open = df_open.append(open, ignore_index=True)
    closed = group[~group.index.isin(open_positions)]
    df_closed = df_closed.append(open, ignore_index=True)

# %%
df_open
# Out:
#      type subAccount settlementDate       orderId  netAmount  \
# 0   TRADE          1     2021-02-09  2.068868e+09    -913.99
# 1   TRADE          1     2021-02-12  2.105036e+09    -187.66
# 2   TRADE          1     2021-02-16  2.114929e+09    -621.33
# 3   TRADE          1     2021-02-09  2.073412e+09    -860.66
# 4   TRADE          1     2021-02-12  2.105435e+09    -106.66
# 5   TRADE          1     2021-02-16  2.113482e+09    -187.66
# 6   TRADE          1     2021-02-10  2.081752e+09    -625.66
# 7   TRADE          1     2021-02-10  2.081316e+09    -495.66
# 8   TRADE          1     2021-02-10  2.082214e+09    -320.66
# 9   TRADE          1     2021-02-12  2.105036e+09    -205.66
# 10  TRADE          1     2021-02-11  2.089462e+09    -595.66
# 11  TRADE          1     2021-02-11  2.093450e+09    -706.99
#
#               transactionDate                 orderDate transactionSubType  \
# 0   2021-02-08 16:08:50+00:00  2021-02-08T16:08:49+0000                 BY
# 1   2021-02-11 20:21:48+00:00  2021-02-11T20:21:35+0000                 BY
# 2   2021-02-12 20:55:58+00:00  2021-02-12T20:55:58+0000                 BY
# 3   2021-02-08 20:47:30+00:00  2021-02-08T20:47:24+0000                 BY
# 4   2021-02-11 20:50:03+00:00  2021-02-11T20:50:03+0000                 BY
# 5   2021-02-12 19:28:54+00:00  2021-02-12T19:28:54+0000                 BY
# 6   2021-02-09 18:50:26+00:00  2021-02-09T18:50:25+0000                 BY
# 7   2021-02-09 18:22:58+00:00  2021-02-09T18:22:41+0000                 BY
# 8   2021-02-09 19:22:08+00:00  2021-02-09T19:22:08+0000                 BY
# 9   2021-02-11 20:22:38+00:00  2021-02-11T20:22:38+0000                 BY
# 10  2021-02-10 15:53:13+00:00  2021-02-10T15:53:09+0000                 BY
# 11  2021-02-10 19:37:48+00:00  2021-02-10T19:37:26+0000                 BY
#
#    transactionId cashBalanceEffectFlag description  \
# 0    32186081337                  True   BUY TRADE
# 1    32549867239                  True   BUY TRADE
# 2    32599479264                  True   BUY TRADE
# 3    32194643318                  True   BUY TRADE
# 4    32550799584                  True   BUY TRADE
# 5    32595505344                  True   BUY TRADE
# 6    32236445199                  True   BUY TRADE
# 7    32235541474                  True   BUY TRADE
# 8    32236955573                  True   BUY TRADE
# 9    32549921079                  True   BUY TRADE
# 10   32275140745                  True   BUY TRADE
# 11   32281559123                  True   BUY TRADE
#
#                                                  fees  \
# 0   {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 1   {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 2   {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 3   {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 4   {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 5   {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 6   {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 7   {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 8   {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 9   {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 10  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
# 11  {'rFee': 0.0, 'additionalFee': 0.0, 'cdscFee':...
#
#                                       transactionItem  totalFees  \
# 0   {'accountId': 275422611, 'amount': 3.0, 'price...       2.03
# 1   {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 2   {'accountId': 275422611, 'amount': 2.0, 'price...       1.36
# 3   {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 4   {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 5   {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 6   {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 7   {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 8   {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 9   {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 10  {'accountId': 275422611, 'amount': 1.0, 'price...       0.67
# 11  {'accountId': 275422611, 'amount': 3.0, 'price...       2.03
#
#                cusip  position_effect
# 0   0AAPL.C510140000              3.0
# 1   0AAPL.C510140000              1.0
# 2   0APHA.CJ10020000              2.0
# 3   0CCIV.CJ10040000              1.0
# 4   0DIS..BJ10220000              1.0
# 5   0FUBO.BJ10050000              1.0
# 6   0JKS..CJ10070000              1.0
# 7   0NPA..CJ10030000              1.0
# 8   0NPA..CJ10030000              1.0
# 9   0NPA..CJ10030000              1.0
# 10  0PLUG.CJ10070000              1.0
# 11  0QCOM.CJ10160000              3.0

# %%
df.transactionItem.apply(lambda x: parse(x['instrument']['optionExpirationDate']))
# Out:
# 0       2021-03-19 05:00:00+00:00
# 1       2021-02-19 06:00:00+00:00
# 2       2021-03-19 05:00:00+00:00
# 3       2021-02-19 06:00:00+00:00
# 4       2021-03-19 05:00:00+00:00
#                   ...
# 1304    2020-09-04 05:00:00+00:00
# 1305    2020-09-04 05:00:00+00:00
# 1306    2020-09-16 05:00:00+00:00
# 1307    2020-09-16 05:00:00+00:00
# 1308    2020-09-18 05:00:00+00:00
# Name: transactionItem, Length: 1305, dtype: object
